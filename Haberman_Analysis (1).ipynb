# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
haberman=pd.read_csv('A:\\learnbay all downloads\\applied ai _downloads\\haberman.csv')
haberman

# age of the patient
# The survey was held between the year #58 to #69
# no of nodes found
# survival status (1 : survived after 5 yeras of treatment, 2: didn't survive till 5 years )
# Out:
#      age  year  nodes  status
# 0     30    64      1       1
# 1     30    62      3       1
# 2     30    65      0       1
# 3     31    59      2       1
# 4     31    65      4       1
# ..   ...   ...    ...     ...
# 301   75    62      1       1
# 302   76    67      0       1
# 303   77    65      3       1
# 304   78    65      1       2
# 305   83    58      2       2
#
# [306 rows x 4 columns]

# %%
haberman.shape
# Out:
# (306, 4)

# %%
haberman.columns
# Out:
# Index(['age', 'year', 'nodes', 'status'], dtype='object')

# %%
haberman['year'].min(),haberman['year'].max()
# Out:
# (58, 69)

# %%
haberman['age'].min(),haberman['age'].max()
# Min age is 30 and max age is 83
# Out:
# (30, 83)

# %%
haberman.describe().T

# 75% of patients has 4 nodes
# age of patients min 30 to max 83: 50% is 44 to 60.75 years
# Out:
#         count       mean        std   min   25%   50%    75%   max
# age     306.0  52.457516  10.803452  30.0  44.0  52.0  60.75  83.0
# year    306.0  62.852941   3.249405  58.0  60.0  63.0  65.75  69.0
# nodes   306.0   4.026144   7.189654   0.0   0.0   1.0   4.00  52.0
# status  306.0   1.264706   0.441899   1.0   1.0   1.0   2.00   2.0

# %%
haberman.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 306 entries, 0 to 305
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   age     306 non-null    int64
#  1   year    306 non-null    int64
#  2   nodes   306 non-null    int64
#  3   status  306 non-null    object
# dtypes: int64(3), object(1)
# memory usage: 9.7+ KB

# %%
haberman['status'] = haberman['status'].map({1:'Yes', 2:'No'})
haberman['status']
# Out:
# 0      Yes
# 1      Yes
# 2      Yes
# 3      Yes
# 4      Yes
#       ...
# 301    Yes
# 302    Yes
# 303    Yes
# 304     No
# 305     No
# Name: status, Length: 306, dtype: object

# %%
haberman
# Out:
#      age  year  nodes status
# 0     30    64      1    Yes
# 1     30    62      3    Yes
# 2     30    65      0    Yes
# 3     31    59      2    Yes
# 4     31    65      4    Yes
# ..   ...   ...    ...    ...
# 301   75    62      1    Yes
# 302   76    67      0    Yes
# 303   77    65      3    Yes
# 304   78    65      1     No
# 305   83    58      2     No
#
# [306 rows x 4 columns]

# %%
haberman['status'].value_counts()
# Out:
# Yes    225
# No      81
# Name: status, dtype: int64

# %%
# % of patients who survived after 5 years
s1=225/306
s1
# Out:
# 0.7352941176470589

# %%
# % of patients who did not survive till 5 years
s2=81/306
s2
# Out:
# 0.2647058823529412

# %%
# Analysis using 2-D pair plot
# We cannot make any conclusion as because overlapping of survived and non survived are very high
# But every cas it is clear no of survival is higher than no of non survival
plt.close()  
sns.set_style("whitegrid");
sns.pairplot(haberman, hue="status", size=3)
plt.show();
# Out:
# C:\Users\SAYANIK\anaconda3\lib\site-packages\seaborn\axisgrid.py:1912: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
## Univariate analysis::(Histogram//PDF)
## No conclusion; Overlapping is very hiogh
sns.set_style("whitegrid");
sns.FacetGrid(haberman, hue ='status', size= 5) \
    .map(sns.distplot, 'age') \
    .add_legend();
plt.show();
# Out:
# C:\Users\SAYANIK\anaconda3\lib\site-packages\seaborn\axisgrid.py:316: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# C:\Users\SAYANIK\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\SAYANIK\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.set_style("whitegrid");
sns.FacetGrid(haberman, hue ='status', size= 5) \
    .map(sns.distplot, 'year') \
    .add_legend();
plt.show();

## No conclusion
# Out:
# C:\Users\SAYANIK\anaconda3\lib\site-packages\seaborn\axisgrid.py:316: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# C:\Users\SAYANIK\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\SAYANIK\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.set_style("whitegrid");
sns.FacetGrid(haberman, hue ='status', size= 5) \
    .map(sns.distplot, 'nodes') \
    .add_legend();
plt.show();

## People who survived greater than 5 years are having less no of nodes (-5<= nodes <=4)
# Out:
# C:\Users\SAYANIK\anaconda3\lib\site-packages\seaborn\axisgrid.py:316: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# C:\Users\SAYANIK\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\SAYANIK\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#  box plot analysis

sns.boxplot(x='status',y='age',data=haberman)
plt.show();

# Those who has survived more tha or equal to 5 years ofrom treatment are all less than 80

# %%
sns.boxplot(x='status',y='year',data=haberman)
plt.show();

# %%
sns.boxplot(x='status',y='nodes',data=haberman)
plt.show();

# here 25% qr roughly 0 nodes,, 75% qr roughly 4 
# IQR = 4-0 = 4
# Lower and Upper Inner Fence roughly -6 and 10  (25% - 1.5*IQR and 75% - 1.5*IQR)
# Lower and Upper outer Fence roughly -12 and 16 (25% - 3*IQR and 75% - 3*IQR)
# No of survived has mostly no of nodes range roughly  0 to 8
# No of  not survived has mostly has nodes of range roughly  1 to 25 
# mild outlier and extreme outlier are there

# %%
haberman
# Out:
#      age  year  nodes status
# 0     30    64      1    Yes
# 1     30    62      3    Yes
# 2     30    65      0    Yes
# 3     31    59      2    Yes
# 4     31    65      4    Yes
# ..   ...   ...    ...    ...
# 301   75    62      1    Yes
# 302   76    67      0    Yes
# 303   77    65      3    Yes
# 304   78    65      1     No
# 305   83    58      2     No
#
# [306 rows x 4 columns]

# %% [markdown]
# ## PDF and CDF anlysis of whole Haberman Data Set

# %%
sns.set_style("whitegrid")
counts, bin_edges = np.histogram(haberman['age'], bins=10, 
                                 density = True)

pdf = counts/(sum(counts))
cdf = np.cumsum(pdf)
print(bin_edges);
print(pdf);
print(cdf)
plt.plot(bin_edges[1:],pdf);
plt.plot(bin_edges[1:], cdf)

plt.xlabel('age')
plt.show()
# Out:
# [30.  35.3 40.6 45.9 51.2 56.5 61.8 67.1 72.4 77.7 83. ]
# [0.05228758 0.08823529 0.1503268  0.17320261 0.17973856 0.13398693
#  0.13398693 0.05882353 0.02287582 0.00653595]
# [0.05228758 0.14052288 0.29084967 0.46405229 0.64379085 0.77777778
#  0.91176471 0.97058824 0.99346405 1.        ]

# %%
counts, bin_edges = np.histogram(haberman['year'], bins=10, 
                                 density = True)
pdf = counts/(sum(counts))
print(bin_edges);
print(pdf);
print(cdf)
cdf = np.cumsum(pdf)
plt.plot(bin_edges[1:],pdf);
plt.plot(bin_edges[1:],cdf)

plt.xlabel('year')
plt.show()
# Out:
# [58.  59.1 60.2 61.3 62.4 63.5 64.6 65.7 66.8 67.9 69. ]
# [0.20588235 0.09150327 0.08496732 0.0751634  0.09803922 0.10130719
#  0.09150327 0.09150327 0.08169935 0.07843137]
# [0.20588235 0.29738562 0.38235294 0.45751634 0.55555556 0.65686275
#  0.74836601 0.83986928 0.92156863 1.        ]

# %%
counts, bin_edges = np.histogram(haberman['nodes'], bins=10, 
                                 density = True)
pdf = counts/(sum(counts))
cdf = np.cumsum(pdf)
print(bin_edges);
print(pdf);
print(cdf)
plt.plot(bin_edges[1:],pdf);
plt.plot(bin_edges[1:], cdf)

plt.xlabel('nodes')
plt.show()

## 77.12% in haberman data set has roughly nodes <=5.2  ------ not in any use
#  86.92% in haberman data set has roughly nodes<=10.4
# Out:
# [ 0.   5.2 10.4 15.6 20.8 26.  31.2 36.4 41.6 46.8 52. ]
# [0.77124183 0.09803922 0.05882353 0.02614379 0.02941176 0.00653595
#  0.00326797 0.         0.00326797 0.00326797]
# [0.77124183 0.86928105 0.92810458 0.95424837 0.98366013 0.99019608
#  0.99346405 0.99346405 0.99673203 1.        ]

# %%
survive = haberman[haberman['status'] == 'Yes']
survive
# Out:
#      age  year  nodes status
# 0     30    64      1    Yes
# 1     30    62      3    Yes
# 2     30    65      0    Yes
# 3     31    59      2    Yes
# 4     31    65      4    Yes
# ..   ...   ...    ...    ...
# 298   73    68      0    Yes
# 300   74    63      0    Yes
# 301   75    62      1    Yes
# 302   76    67      0    Yes
# 303   77    65      3    Yes
#
# [225 rows x 4 columns]

# %%
not_survive = haberman[haberman['status'] == 'No']
not_survive
# Out:
#      age  year  nodes status
# 7     34    59      0     No
# 8     34    66      9     No
# 24    38    69     21     No
# 34    39    66      0     No
# 43    41    60     23     No
# ..   ...   ...    ...    ...
# 286   70    58      4     No
# 293   72    63      0     No
# 299   74    65      3     No
# 304   78    65      1     No
# 305   83    58      2     No
#
# [81 rows x 4 columns]

# %% [markdown]
# ## PDF and CDF of survived patients on  parameters

# %%
sns.set_style("whitegrid")
age_counts, bin_edges = np.histogram(survive['age'], bins=10, 
                                 density = True)

pdf = age_counts/(sum(age_counts))
cdf = np.cumsum(pdf)
print(bin_edges);
print(pdf);
print(cdf)
plt.plot(bin_edges[1:],pdf);
plt.plot(bin_edges[1:], cdf)

plt.title('PDF and CDF of survived patients on age parameter')
plt.xlabel('age')
plt.show()
# Out:
# [30.  34.7 39.4 44.1 48.8 53.5 58.2 62.9 67.6 72.3 77. ]
# [0.05333333 0.10666667 0.12444444 0.09333333 0.16444444 0.16444444
#  0.09333333 0.11111111 0.06222222 0.02666667]
# [0.05333333 0.16       0.28444444 0.37777778 0.54222222 0.70666667
#  0.8        0.91111111 0.97333333 1.        ]

# %%
sns.set_style("whitegrid")
year_counts, bin_edges = np.histogram(survive['year'], bins=10, 
                                 density = True)

pdf = year_counts/(sum(year_counts))
cdf = np.cumsum(pdf)
print(bin_edges);
print(pdf);
print(cdf)
plt.plot(bin_edges[1:],pdf);
plt.plot(bin_edges[1:], cdf)

plt.title('PDF and CDF of survived patients on year parameter')
plt.xlabel('year')
plt.show()
# Out:
# [58.  59.1 60.2 61.3 62.4 63.5 64.6 65.7 66.8 67.9 69. ]
# [0.18666667 0.10666667 0.10222222 0.07111111 0.09777778 0.10222222
#  0.06666667 0.09777778 0.09333333 0.07555556]
# [0.18666667 0.29333333 0.39555556 0.46666667 0.56444444 0.66666667
#  0.73333333 0.83111111 0.92444444 1.        ]

# %%
sns.set_style("whitegrid")
nodes_counts, bin_edges = np.histogram(survive['nodes'], bins=10, 
                                 density = True)

pdf = nodes_counts/(sum(nodes_counts))
cdf = np.cumsum(pdf)
print(bin_edges);
print(pdf);
print(cdf)
plt.plot(bin_edges[1:],pdf);
plt.plot(bin_edges[1:], cdf)

plt.title('PDF and CDF of survived patients on nodes parameter')
plt.xlabel('nodes')
plt.show()
# Out:
# [ 0.   4.6  9.2 13.8 18.4 23.  27.6 32.2 36.8 41.4 46. ]
# [0.83555556 0.08       0.02222222 0.02666667 0.01777778 0.00444444
#  0.00888889 0.         0.         0.00444444]
# [0.83555556 0.91555556 0.93777778 0.96444444 0.98222222 0.98666667
#  0.99555556 0.99555556 0.99555556 1.        ]

# %% [markdown]
# ## PDF and CDF on Not survived patients on different parameters

# %%
sns.set_style("whitegrid")
age1_counts, bin_edges = np.histogram(not_survive['age'], bins=10, 
                                 density = True)

pdf = age1_counts/(sum(age1_counts))
cdf = np.cumsum(pdf)
print(bin_edges);
print(pdf);
print(cdf)
plt.plot(bin_edges[1:],pdf);
plt.plot(bin_edges[1:], cdf)

plt.title('PDF and CDF of not survived patients on age parameter')
plt.xlabel('age')
plt.show()
# Out:
# [34.  38.9 43.8 48.7 53.6 58.5 63.4 68.3 73.2 78.1 83. ]
# [0.03703704 0.12345679 0.19753086 0.19753086 0.13580247 0.12345679
#  0.09876543 0.04938272 0.02469136 0.01234568]
# [0.03703704 0.16049383 0.35802469 0.55555556 0.69135802 0.81481481
#  0.91358025 0.96296296 0.98765432 1.        ]

# %%
sns.set_style("whitegrid")
year1_counts, bin_edges = np.histogram(not_survive['year'], bins=10, 
                                 density = True)

pdf = year1_counts/(sum(year1_counts))
cdf = np.cumsum(pdf)
print(bin_edges);
print(pdf);
print(cdf)
plt.plot(bin_edges[1:],pdf);
plt.plot(bin_edges[1:], cdf)

plt.title('PDF and CDF of not survived patients on year parameter')
plt.xlabel('year')
plt.show()
# Out:
# [58.  59.1 60.2 61.3 62.4 63.5 64.6 65.7 66.8 67.9 69. ]
# [0.25925926 0.04938272 0.03703704 0.08641975 0.09876543 0.09876543
#  0.16049383 0.07407407 0.04938272 0.08641975]
# [0.25925926 0.30864198 0.34567901 0.43209877 0.5308642  0.62962963
#  0.79012346 0.86419753 0.91358025 1.        ]

# %%
sns.set_style("whitegrid")
nodes1_counts, bin_edges = np.histogram(not_survive['nodes'], bins=10, 
                                 density = True)

pdf = nodes1_counts/(sum(nodes1_counts))
cdf = np.cumsum(pdf)
print(bin_edges);
print(pdf);
print(cdf)
plt.plot(bin_edges[1:],pdf);
plt.plot(bin_edges[1:], cdf)

plt.title('PDF and CDF of not survived patients on nodes parameter')
plt.xlabel('nodes')
plt.show()
# Out:
# [ 0.   5.2 10.4 15.6 20.8 26.  31.2 36.4 41.6 46.8 52. ]
# [0.56790123 0.14814815 0.13580247 0.04938272 0.07407407 0.
#  0.01234568 0.         0.         0.01234568]
# [0.56790123 0.71604938 0.85185185 0.90123457 0.97530864 0.97530864
#  0.98765432 0.98765432 0.98765432 1.        ]

# %%
## there is nothing much conclusion when it comes to the copmparison between status and year or status and age
## Roughly 83% of people having nodes less tahn or equal to 5.
## So patients with lower no of nodes having the survival year of 5 or more
